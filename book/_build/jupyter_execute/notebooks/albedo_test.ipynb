# %% [markdown]
# # Albedo Testing

# %% [markdown]
# Surface albedo parameterization testing and validation for different surface types.

# %%
# Import PyRadtran components using NEW IO system
from pyradtran.interface import PyRadtranAccessor  # This should register the accessor automatically
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
from pathlib import Path
import pandas as pd

# Load the configuration from the YAML file
config_path = Path('config/albedo.yaml')
import logging
# change to "DEBUG" if you want to see more output
logging.getLogger('pyradtran').setLevel(logging.CRITICAL)

N_timesteps = 24

# stationary simulation at constant altitude, latitude, and longitude but with varying time
ds = xr.Dataset(
    coords={
        'time' : pd.date_range('2025-04-04T12:00:00', periods=N_timesteps, freq='s'),
        'latitude' : ('time', [51.3406321] * N_timesteps),
        'longitude' : ('time', [12.3747329] * N_timesteps),
        'altitude' : ('altitude', np.arange(0, 110, 10) ),

    },
    data_vars={
        'albedo' : ('time', np.linspace(0.1, 0.9, N_timesteps)),
    }
)
# Run a spectral simulation for a single point using NEW IO system
ds_sim = ds.pyradtran.run_uvspec(
    config_path=config_path,
    return_dataset=True,
    save_to_file=True,
    albedo_var='albedo',
)

print("\nSimulation complete!")
print(f"Dataset variables: {list(ds_sim.data_vars.keys())}")
print(f"Dataset coordinates: {list(ds_sim.coords.keys())}")
print(f"Dataset shape: {ds_sim.dims}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 31
#      18 ds = xr.Dataset(
#      19     coords={
#      20         'time' : pd.date_range('2025-04-04T12:00:00', periods=N_timesteps, freq='s'),
#    (...)
#      28     }
#      29 )
#      30 # Run a spectral simulation for a single point using NEW IO system
# ---> 31 ds_sim = ds.pyradtran.run_uvspec(
#      32     config_path=config_path,
#      33     return_dataset=True,
#      34     save_to_file=True,
#      35     albedo_var='albedo',
#      36 )
#      38 print("\nSimulation complete!")
#      39 print(f"Dataset variables: {list(ds_sim.data_vars.keys())}")
#
# File /projekt_agmwend/home_rad/Joshua/HALO-AC3_Arctic_leads/sim/pyradtran/pyradtran/interface.py:390, in PyRadtranAccessor.run_uvspec(self, config_path, output_path, parameter_overrides, time_var, lat_var, lon_var, albedo_var, surface_temperature_var, era5_atmosphere, return_dataset, save_to_file, progress_callback)
#     365 """
#     366 Run uvspec for each time/location coordinate in the dataset using the new IO system.
#     367
#    (...)
#     387     PyRadtranError: If simulation fails
#     388 """
#     389 # Load configuration
# --> 390 self._config = load_config(config_path)
#     392 # Apply parameter overrides if provided
#     393 if parameter_overrides:
#     394     # Apply parameter overrides to config
#
# File /projekt_agmwend/home_rad/Joshua/HALO-AC3_Arctic_leads/sim/pyradtran/pyradtran/config.py:344, in load_config(config_path)
#     341     logger.info(f"Loading configuration from: {config_path}")
#     343 try:
# --> 344     config = SimulationConfig.from_yaml(config_path)
#     345     logger.info("Configuration loaded successfully.")
#     346     # Set logging level based on config after loading
#
# File /projekt_agmwend/home_rad/Joshua/HALO-AC3_Arctic_leads/sim/pyradtran/pyradtran/config.py:271, in SimulationConfig.from_yaml(cls, yaml_path)
#     269 yaml_path = Path(yaml_path)
#     270 if not yaml_path.is_file():
# --> 271     raise FileNotFoundError(f"Configuration file not found: {yaml_path}")
#     273 with open(yaml_path, 'r') as f:
#     274     raw_config = yaml.safe_load(f)
#
# FileNotFoundError: Configuration file not found: config/albedo.yaml

# %%
ds_sim['enet'].plot(y='altitude')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ds_sim['enet'].plot(y='altitude')
#
# NameError: name 'ds_sim' is not defined

# %% [markdown]
# ## Results
#
# Comparison of simulated radiation with different albedo configurations.

# %%
ds_sim.sel(altitude=0).plot.scatter(
    x = 'albedo',
    y = 'eup'
)
plt.title('Upwelling Integrated Irradiance (400nm - 700nm) vs Albedo - NEW IO System')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ds_sim.sel(altitude=0).plot.scatter(
#       2     x = 'albedo',
#       3     y = 'eup'
#       4 )
#       5 plt.title('Upwelling Integrated Irradiance (400nm - 700nm) vs Albedo - NEW IO System')
#
# NameError: name 'ds_sim' is not defined
